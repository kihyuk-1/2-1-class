# %% [markdown]
# <a href="https://colab.research.google.com/github/kihyuk-1/2-1-class/blob/main/inclass/06w_B_wed_0409_easy_ch06_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 단원 06-05 파생변수 추가

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 5.39 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
import pandas as pd
import numpy as np

# %%
exam = pd.read_csv('data/exam.csv')
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# total 변수 추가

exam.assign(total = exam['math']+ exam['english']+ exam['science'])
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
exam.head(3)
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78

# %%
exam.assign(total = exam['math']+ exam['english']+ exam['science'],
            mean = (exam['math']+ exam['english']+ exam['science']) /3)
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %%
exam.assign(test = np.where())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-039e49a1d0fd> in <cell line: 0>()
# ----> 1 exam.assign(test = np.where())
#
# TypeError: where() missing 1 required positional argument: 'condition'

# %%
exam = pd.read_csv('data/exam.csv')
exam.sample(frac=.3)
# Out:
#     id  nclass  math  english  science
# 12  13       4    46       98       65
# 0    1       1    50       98       50
# 16  17       5    65       68       98
# 8    9       3    20       98       15
# 10  11       3    65       65       65
# 17  18       5    80       78       90

# %%
exam.assign(total = exam.math + exam.english + exam.science)
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
exam.assign(total = exam.math + exam.english + exam.science).sort_values('total')
# Out:
#     id  nclass  math  english  science  total
# 8    9       3    20       98       15    133
# 13  14       4    48       87       12    147
# 11  12       3    45       85       32    162
# 4    5       2    25       80       65    170
# 3    4       1    30       98       58    186
# 9   10       3    50       98       45    193
# 7    8       2    90       78       25    193
# 10  11       3    65       65       65    195
# 0    1       1    50       98       50    198
# 12  13       4    46       98       65    209
# 14  15       4    75       56       78    209
# 2    3       1    45       86       78    209
# 6    7       2    80       90       45    215
# 1    2       1    60       97       60    217
# 19  20       5    78       83       58    219
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 5    6       2    50       89       98    237
# 18  19       5    89       68       87    244
# ...

# %%
exam.assign(total = exam.math + exam.english + exam.science).sort_values('total' , ascending=False)
# Out:
#     id  nclass  math  english  science  total
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# 5    6       2    50       89       98    237
# 16  17       5    65       68       98    231
# 15  16       4    58       98       65    221
# 19  20       5    78       83       58    219
# 1    2       1    60       97       60    217
# 6    7       2    80       90       45    215
# 14  15       4    75       56       78    209
# 12  13       4    46       98       65    209
# 2    3       1    45       86       78    209
# 0    1       1    50       98       50    198
# 10  11       3    65       65       65    195
# 7    8       2    90       78       25    193
# 9   10       3    50       98       45    193
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 11  12       3    45       85       32    162
# 13  14       4    48       87       12    147
# ...

# %% [markdown]
# # 람다 함수

# %%
(lambda x , y : x + y)(30,40)
# Out:
# 70

# %%
f = lambda x, y : x + y
f(30,4)
# Out:
# 34

# %%
exam.assign(total = exam.math + aexam.english + exam.science , mean = lambda x : x.total / 3)
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %%
round(3.45678 , 2)
# Out:
# 3.46

# %%
exam.assign(total = exam.math + exam.english + exam.science , mean = lambda x : x.round(x.total / 3.3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-1e6423aedec0> in <cell line: 0>()
# ----> 1 exam.assign(total = exam.math + exam.english + exam.science , mean = lambda x : x.round(x.total / 3.3))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in assign(self, **kwargs)
#    5237
#    5238         for k, v in kwargs.items():
# -> 5239             data[k] = com.apply_if_callable(v, data)
#    5240         return data
#    5241
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/common.py in apply_if_callable(maybe_callable, obj, **kwargs)
#     382     """
#     383     if callable(maybe_callable):
# --> 384         return maybe_callable(obj, **kwargs)
#     385
#     386     return maybe_callable
#
# <ipython-input-26-1e6423aedec0> in <lambda>(x)
# ...

# %%
pd.set_option('display.precision', 2)

# %%
exam.assign(total = exam.math + exam.english + exam.science , mean = lambda x : x.total / 3)
# Out:
#     id  nclass  math  english  science  total   mean
# 0    1       1    50       98       50    198  66.00
# 1    2       1    60       97       60    217  72.33
# 2    3       1    45       86       78    209  69.67
# 3    4       1    30       98       58    186  62.00
# 4    5       2    25       80       65    170  56.67
# 5    6       2    50       89       98    237  79.00
# 6    7       2    80       90       45    215  71.67
# 7    8       2    90       78       25    193  64.33
# 8    9       3    20       98       15    133  44.33
# 9   10       3    50       98       45    193  64.33
# 10  11       3    65       65       65    195  65.00
# 11  12       3    45       85       32    162  54.00
# 12  13       4    46       98       65    209  69.67
# 13  14       4    48       87       12    147  49.00
# 14  15       4    75       56       78    209  69.67
# 15  16       4    58       98       65    221  73.67
# 16  17       5    65       68       98    231  77.00
# ...

# %%
exam.assign(total = lambda x :  x.math + x.english + x.science , mean = lambda x : x.total / 3)
# Out:
#     id  nclass  math  english  science  total   mean
# 0    1       1    50       98       50    198  66.00
# 1    2       1    60       97       60    217  72.33
# 2    3       1    45       86       78    209  69.67
# 3    4       1    30       98       58    186  62.00
# 4    5       2    25       80       65    170  56.67
# 5    6       2    50       89       98    237  79.00
# 6    7       2    80       90       45    215  71.67
# 7    8       2    90       78       25    193  64.33
# 8    9       3    20       98       15    133  44.33
# 9   10       3    50       98       45    193  64.33
# 10  11       3    65       65       65    195  65.00
# 11  12       3    45       85       32    162  54.00
# 12  13       4    46       98       65    209  69.67
# 13  14       4    48       87       12    147  49.00
# 14  15       4    75       56       78    209  69.67
# 15  16       4    58       98       65    221  73.67
# 16  17       5    65       68       98    231  77.00
# ...

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'] , mean = exam['total']/3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-f9f73c7a6681> in <cell line: 0>()
# ...

# %%
exam.agg("mean")
# Out:
# id         10.50
# nclass      3.00
# math       57.45
# english    84.90
# science    59.45
# dtype: float64

# %%
exam.mean()
# Out:
# id         10.50
# nclass      3.00
# math       57.45
# english    84.90
# science    59.45
# dtype: float64

# %%
exam.agg(["mean" , "max" , "min" , "median"])
# Out:
#           id  nclass   math  english  science
# mean    10.5     3.0  57.45     84.9    59.45
# max     20.0     5.0  90.00     98.0    98.00
# min      1.0     1.0  20.00     56.0    12.00
# median  10.5     3.0  54.00     86.5    62.50

# %%
exam.describe()
# Out:
#           id  nclass   math  english  science
# count  20.00   20.00  20.00    20.00    20.00
# mean   10.50    3.00  57.45    84.90    59.45
# std     5.92    1.45  20.30    12.88    25.29
# min     1.00    1.00  20.00    56.00    12.00
# 25%     5.75    2.00  45.75    78.00    45.00
# 50%    10.50    3.00  54.00    86.50    62.50
# 75%    15.25    4.00  75.75    98.00    78.00
# max    20.00    5.00  90.00    98.00    98.00

# %%
exam.agg(mean_math = ("math" , "mean"))
# Out:
#             math
# mean_math  57.45

# %% [markdown]
# # 단원 06 종료

# %%
df = pd.DataFrame([[1,2,3] ,
                   [4,5,6] ,
                   [7,8,9] ,
                   [np.nan , np.nan , 10]] ,
                    columns = ['A' , 'B' , 'C'])
df
# Out:
#      A    B   C
# 0  1.0  2.0   3
# 1  4.0  5.0   6
# 2  7.0  8.0   9
# 3  NaN  NaN  10

# %%
df.agg(["sum" , 'mean' , 'median' , 'min' , 'max' , 'count'])
# Out:
#            A     B     C
# sum     12.0  15.0  28.0
# mean     4.0   5.0   7.0
# median   4.0   5.0   7.5
# min      1.0   2.0   3.0
# max      7.0   8.0  10.0
# count    3.0   3.0   4.0

# %%
df.agg(["sum" , 'mean' , 'median' , 'min' , 'max' , 'count'] , axis=1)
# Out:
#     sum  mean  median   min   max  count
# 0   6.0   2.0     2.0   1.0   3.0    3.0
# 1  15.0   5.0     5.0   4.0   6.0    3.0
# 2  24.0   8.0     8.0   7.0   9.0    3.0
# 3  10.0  10.0    10.0  10.0  10.0    1.0

# %%
df.agg(["sum" , 'mean' , 'median' , 'min' , 'max' , 'count'], axis='columns')
# Out:
#     sum  mean  median   min   max  count
# 0   6.0   2.0     2.0   1.0   3.0    3.0
# 1  15.0   5.0     5.0   4.0   6.0    3.0
# 2  24.0   8.0     8.0   7.0   9.0    3.0
# 3  10.0  10.0    10.0  10.0  10.0    1.0

# %%
exam.groupby('nclass').agg(mean_math  = ('math' , 'mean'))
# Out:
#         mean_math
# nclass
# 1           46.25
# 2           61.25
# 3           45.00
# 4           56.75
# 5           78.00

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.groupby('nclass').mean()
# Out:
#           id   math  english  science
# nclass
# 1        2.5  46.25    94.75    61.50
# 2        6.5  61.25    84.25    58.25
# 3       10.5  45.00    86.50    39.25
# 4       14.5  56.75    84.75    55.00
# 5       18.5  78.00    74.25    83.25

# %%
exam.groupby('nclass').mean()[["math" , "science"]]
# Out:
#          math  science
# nclass
# 1       46.25    61.50
# 2       61.25    58.25
# 3       45.00    39.25
# 4       56.75    55.00
# 5       78.00    83.25

# %%
exam.groupby('nclass').mean()[["math" , "science"]]
# Out:
#          math  science
# nclass
# 1       46.25    61.50
# 2       61.25    58.25
# 3       45.00    39.25
# 4       56.75    55.00
# 5       78.00    83.25

# %%
exam.groupby('nclass').mean()[["math"]]
# Out:
#          math
# nclass
# 1       46.25
# 2       61.25
# 3       45.00
# 4       56.75
# 5       78.00

# %%
exam.groupby('nclass').age(mean_math = ('math' , 'mean'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-ac3facc7676a> in <cell line: 0>()
# ----> 1 exam.groupby('nclass').age(mean_math = ('math' , 'mean'))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#    1361             return self[attr]
#    1362
# -> 1363         raise AttributeError(
#    1364             f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'age'

# %%
exam.groupby('nclass').agg(mean_math = ('math' , 'mean'))

# %%
mpg.query('manufacturer == "audi"').groupby('[drv]').agg(n = ('drv' , 'count'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-5717475b0b09> in <cell line: 0>()
# ----> 1 mpg.query('manufacturer == "audi"').groupby('[drv]').agg(n = ('drv' , 'count'))
#
# NameError: name 'mpg' is not defined

# %%
import pandas as pd

mpg = pd.read_csv('data/mpg.csv')
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'category'],
#       dtype='object')

# %%
mpg.sample(frac=.02)
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 182       toyota         camry    2.4  2008    4    auto(l5)   f   21   31  r
# 212   volkswagen         jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 189       toyota  camry solara    2.4  2008    4    auto(s5)   f   22   31  r
# 141       nissan        altima    2.4  1999    4  manual(m5)   f   21   29  r
# 216   volkswagen         jetta    2.0  2008    4  manual(m6)   f   21   29  p
#
#     category
# 182  midsize
# 212  compact
# 189  compact
# 141  compact
# 216  compact

# %%
mpg['drv'].value_counts().to_frame('n')
# Out:
#        n
# drv
# f    106
# 4    103
# r     25

# %%
mpg['drv'].value_counts().to_frame('n'.rename_axis  )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-a2ce0d124917> in <cell line: 0>()
# ----> 1 mpg['drv'].value_counts().to_frame('n'.rename_axis  )
#
# AttributeError: 'str' object has no attribute 'rename_axis'

# %%
mpg.query('category == "suv') \ .assign(total = (mpg.hwyy + mpg.cty) / 2) \ .groupby('drv') \ .groupby
# Out:
#   File "<ipython-input-65-e6ec6e848a93>", line 1
#     mpg.query('category == "suv') \ .assign(total = (mpg.hwyy + mpg.cty) / 2)
#                                    ^
# SyntaxError: unexpected character after line continuation character

# %%
mpg.query('category == "suv"') \ .assign(total = (mpg.hwy + mpg.cty) / 2) \ .groupby('drv') \ .agg(mean_total = ('total' , 'mean')) \ .np.sort_values("mean_total" , ascending=False)
# Out:
#   File "<ipython-input-67-a82d6ae1d4e9>", line 1
#     mpg.query('category == "suv"') \ .assign(total = (mpg.hwy + mpg.cty) / 2) \ .groupby('drv') \ .agg(mean_total = ('total' , 'mean')) \ .np.sort_values("mean_total" , ascending=False)
#                                     ^
# SyntaxError: unexpected character after line continuation character

# %% [markdown]
# # merge() 중간고사 예상 문제

# %%
df1 = pd.DataFrame([)
